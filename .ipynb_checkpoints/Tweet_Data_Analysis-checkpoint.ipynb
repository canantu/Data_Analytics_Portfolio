# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import string
from nltk.corpus import stopwords

import spacy

import nltk
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from collections import defaultdict
from collections import  Counter

# %%
data= pd.read_csv('result.csv')
data.head()
# Out:
#                    timestamp  \
# 0  2021-12-09 17:00:12+00:00
# 1  2021-12-02 16:38:09+00:00
# 2  2021-12-01 14:29:59+00:00
# 3  2021-11-11 14:00:19+00:00
# 4  2021-11-03 13:15:11+00:00
#
#                                           tweet_text
# 0  Today we shared details about how @CVSHealth i...
# 1  It was a pleasure to join @Microsoft CEO @Saty...
# 2  Congratulations to this year’s #Bloomberg50. I...
# 3  On #VeteransDay, I want to recognize and thank...
# 4  Earlier today @CVSHealth posted third quarter ...

# %%
stop = stopwords.words('english')

# %%
df = data.copy()

# %%
def remove_URL(text):
    
    return re.sub(r'https?://\S+|www\.\S+', r'',text)

# %%
df['tweet_text']=df['tweet_text'].apply(lambda x : remove_URL(x))
df
# Out:
#                      timestamp  \
# 0    2021-12-09 17:00:12+00:00
# 1    2021-12-02 16:38:09+00:00
# 2    2021-12-01 14:29:59+00:00
# 3    2021-11-11 14:00:19+00:00
# 4    2021-11-03 13:15:11+00:00
# ..                         ...
# 829  2017-08-24 15:05:29+00:00
# 830  2017-08-23 22:00:17+00:00
# 831  2017-08-23 20:57:36+00:00
# 832  2017-08-23 20:16:12+00:00
# 833  2017-08-23 00:04:07+00:00
#
#                                             tweet_text
# 0    Today we shared details about how @CVSHealth i...
# 1    It was a pleasure to join @Microsoft CEO @Saty...
# 2    Congratulations to this year’s #Bloomberg50. I...
# 3    On #VeteransDay, I want to recognize and thank...
# 4    Earlier today @CVSHealth posted third quarter ...
# ..                                                 ...
# 829  Thank you @GovMattBevin for being an ally in t...
# 830  With @AbleTo_Health, we provide consumers with...
# 831  RT @GovMattBevin: We don't have the luxury of ...
# 832  Proud of our efforts to combat the opioid epid...
# 833  I’m excited to join the online conversation as...
#
# [834 rows x 2 columns]

# %%
sw = stopwords.words('english')

# %%
for i in ["i'm",'i’m', "i'd", "i'll", "there's", "there're", "he's", "he'd", "he'll", "she's", "she'd", "she'll", 
          "they're", "they'd", "they'll", "they've", "we're", "we've", "we'll", "it'll", "it'd", 'us']:
    sw.append(i)

# %%
def remove_stop(text):
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    return " ".join(text)

# %%
df['tweet_text'] = df['tweet_text'].apply(remove_stop)
df
# Out:
#                      timestamp  \
# 0    2021-12-09 17:00:12+00:00
# 1    2021-12-02 16:38:09+00:00
# 2    2021-12-01 14:29:59+00:00
# 3    2021-11-11 14:00:19+00:00
# 4    2021-11-03 13:15:11+00:00
# ..                         ...
# 829  2017-08-24 15:05:29+00:00
# 830  2017-08-23 22:00:17+00:00
# 831  2017-08-23 20:57:36+00:00
# 832  2017-08-23 20:16:12+00:00
# 833  2017-08-23 00:04:07+00:00
#
#                                             tweet_text
# 0    today shared details revolutionizing consumer ...
# 1    pleasure join ceo healthcare summit discussion...
# 2    congratulations year’s bloomberg50 honored rec...
# 3    veteransday want recognize thank colleagues ve...
# 4    earlier today posted third quarter 2021 earnin...
# ..                                                 ...
# 829            thank ally fight opioids dontletthemdie
# 830  provide consumers access personalized behavior...
# 831  luxury pretending problem helping address issu...
# 832  proud efforts combat opioid epidemic providing...
# 833  excited join online conversation advocate holi...
#
# [834 rows x 2 columns]

# %%
## removing words start with @
def remove_at(text):
    at_pattern = re.compile("(\s)@\w+|@\w+")
    return at_pattern.sub(r'',text)

# %%
df['tweet_text']=df['tweet_text'].apply(lambda x: remove_at(x))
df
# Out:
#                      timestamp  \
# 0    2021-12-09 17:00:12+00:00
# 1    2021-12-02 16:38:09+00:00
# 2    2021-12-01 14:29:59+00:00
# 3    2021-11-11 14:00:19+00:00
# 4    2021-11-03 13:15:11+00:00
# ..                         ...
# 829  2017-08-24 15:05:29+00:00
# 830  2017-08-23 22:00:17+00:00
# 831  2017-08-23 20:57:36+00:00
# 832  2017-08-23 20:16:12+00:00
# 833  2017-08-23 00:04:07+00:00
#
#                                             tweet_text
# 0    today shared details revolutionizing consumer ...
# 1    pleasure join ceo healthcare summit discussion...
# 2    congratulations year’s bloomberg50 honored rec...
# 3    veteransday want recognize thank colleagues ve...
# 4    earlier today posted third quarter 2021 earnin...
# ..                                                 ...
# 829            thank ally fight opioids dontletthemdie
# 830  provide consumers access personalized behavior...
# 831  luxury pretending problem helping address issu...
# 832  proud efforts combat opioid epidemic providing...
# 833  excited join online conversation advocate holi...
#
# [834 rows x 2 columns]

# %%
def remove_punctuation(text):
    
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# %%
df['tweet_text'] = df['tweet_text'].apply(remove_punctuation)
df
# Out:
#                      timestamp  \
# 0    2021-12-09 17:00:12+00:00
# 1    2021-12-02 16:38:09+00:00
# 2    2021-12-01 14:29:59+00:00
# 3    2021-11-11 14:00:19+00:00
# 4    2021-11-03 13:15:11+00:00
# ..                         ...
# 829  2017-08-24 15:05:29+00:00
# 830  2017-08-23 22:00:17+00:00
# 831  2017-08-23 20:57:36+00:00
# 832  2017-08-23 20:16:12+00:00
# 833  2017-08-23 00:04:07+00:00
#
#                                             tweet_text
# 0    today shared details revolutionizing consumer ...
# 1    pleasure join ceo healthcare summit discussion...
# 2    congratulations year’s bloomberg50 honored rec...
# 3    veteransday want recognize thank colleagues ve...
# 4    earlier today posted third quarter 2021 earnin...
# ..                                                 ...
# 829            thank ally fight opioids dontletthemdie
# 830  provide consumers access personalized behavior...
# 831  luxury pretending problem helping address issu...
# 832  proud efforts combat opioid epidemic providing...
# 833  excited join online conversation advocate holi...
#
# [834 rows x 2 columns]

# %%
## removing specific unusefull words...
def remove_words(text):
    word_pattern = re.compile('pm\s|pm$|am\s|am$|tbt\s|tbt$|rt\s|rt$|gmt\s|gmt$|pt\s|pt$|')
    return word_pattern.sub(r'',text)

# %%
df['tweet_text']=df['tweet_text'].apply(lambda x: remove_words(x))
df
# Out:
#                      timestamp  \
# 0    2021-12-09 17:00:12+00:00
# 1    2021-12-02 16:38:09+00:00
# 2    2021-12-01 14:29:59+00:00
# 3    2021-11-11 14:00:19+00:00
# 4    2021-11-03 13:15:11+00:00
# ..                         ...
# 829  2017-08-24 15:05:29+00:00
# 830  2017-08-23 22:00:17+00:00
# 831  2017-08-23 20:57:36+00:00
# 832  2017-08-23 20:16:12+00:00
# 833  2017-08-23 00:04:07+00:00
#
#                                             tweet_text
# 0    today shared details revolutionizing consumer ...
# 1    pleasure join ceo healthcare summit discussion...
# 2    congratulations year’s bloomberg50 honored rec...
# 3    veteransday want recognize thank colleagues ve...
# 4    earlier today posted third quarter 2021 earnin...
# ..                                                 ...
# 829            thank ally fight opioids dontletthemdie
# 830  provide consumers access personalized behavior...
# 831  luxury pretending problem helping address issu...
# 832  proud efforts combat opioid epidemic providing...
# 833  excited join online conversation advocate holi...
#
# [834 rows x 2 columns]

# %%
def remove_whites(text):
    
    return ' '.join(text.split())

# %%
df['tweet_text']=df['tweet_text'].apply(lambda x: remove_whites(x))
df
# Out:
#                      timestamp  \
# 0    2021-12-09 17:00:12+00:00
# 1    2021-12-02 16:38:09+00:00
# 2    2021-12-01 14:29:59+00:00
# 3    2021-11-11 14:00:19+00:00
# 4    2021-11-03 13:15:11+00:00
# ..                         ...
# 829  2017-08-24 15:05:29+00:00
# 830  2017-08-23 22:00:17+00:00
# 831  2017-08-23 20:57:36+00:00
# 832  2017-08-23 20:16:12+00:00
# 833  2017-08-23 00:04:07+00:00
#
#                                             tweet_text
# 0    today shared details revolutionizing consumer ...
# 1    pleasure join ceo healthcare summit discussion...
# 2    congratulations year’s bloomberg50 honored rec...
# 3    veteransday want recognize thank colleagues ve...
# 4    earlier today posted third quarter 2021 earnin...
# ..                                                 ...
# 829            thank ally fight opioids dontletthemdie
# 830  provide consumers access personalized behavior...
# 831  luxury pretending problem helping address issu...
# 832  proud efforts combat opioid epidemic providing...
# 833  excited join online conversation advocate holi...
#
# [834 rows x 2 columns]

# %%
df_nlp = df.copy()

# %%
nlp = spacy.load('en')
doc = df_nlp['tweet_text'].apply(nlp)

# %%
##lemmatization

for i, sent in enumerate(doc):
    df_nlp.loc[i, 'lemma']=' '.join([token.lemma_ for token in sent])

# %%
df_nlp
# Out:
#                      timestamp  \
# 0    2021-12-09 17:00:12+00:00
# 1    2021-12-02 16:38:09+00:00
# 2    2021-12-01 14:29:59+00:00
# 3    2021-11-11 14:00:19+00:00
# 4    2021-11-03 13:15:11+00:00
# ..                         ...
# 829  2017-08-24 15:05:29+00:00
# 830  2017-08-23 22:00:17+00:00
# 831  2017-08-23 20:57:36+00:00
# 832  2017-08-23 20:16:12+00:00
# 833  2017-08-23 00:04:07+00:00
#
#                                             tweet_text  \
# 0    today shared details revolutionizing consumer ...
# 1    pleasure join ceo healthcare summit discussion...
# 2    congratulations year’s bloomberg50 honored rec...
# 3    veteransday want recognize thank colleagues ve...
# 4    earlier today posted third quarter 2021 earnin...
# ..                                                 ...
# 829            thank ally fight opioids dontletthemdie
# 830  provide consumers access personalized behavior...
# 831  luxury pretending problem helping address issu...
# 832  proud efforts combat opioid epidemic providing...
# 833  excited join online conversation advocate holi...
#
#                                                  lemma
# 0    today share detail revolutionize consumer heal...
# 1    pleasure join ceo healthcare summit discussion...
# 2    congratulation year ’s bloomberg50 honor recog...
# 3    veteransday want recognize thank colleague vet...
# 4    early today post third quarter 2021 earning re...
# ..                                                 ...
# 829            thank ally fight opioids dontletthemdie
# 830  provide consumer access personalize behavioral...
# 831  luxury pretend problem help address issue head...
# 832  proud effort combat opioid epidemic provide na...
# 833  excited join online conversation advocate holi...
#
# [834 rows x 3 columns]

# %%
corpus=[]
for sent in df_nlp['lemma']:
    for word in sent.split():
        corpus.append(word)

# %%
word_counts = Counter(corpus).most_common(40)
dict_word = dict(word_counts)
plt.figure(figsize=(10,5))
plt.bar(dict_word.keys(), dict_word.values())
plt.title('Frequent words in non-disaster tweets')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
